# %% [markdown]
# # Projeto - Case VAI Shoes
# ##0 - Instalando e importando bibliotecas
# Nesta etapa instalamos e importamos as principais bibliotecas utilizadas na construção do notebook.

# %%
# Import das libs utilizadas

# Manipulação de dados
import pickle
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import re
from textwrap import wrap
# Gráficos
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
# Modelagem - Clusterização
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from sqlalchemy import create_engine
# Modelagem - Regressão
# Modelagem - Série Temporal
from keras.models import Sequential #!pip install keras e !pip install tensorflow
from keras.layers import Dense, Dropout, LSTM
from sklearn.preprocessing import StandardScaler #!pip install sklearn
from keras.callbacks import ModelCheckpoint
#Importando fbprophet
from prophet import Prophet #maneira de instalação e importação mudou recentemente
# Modelagem - Análise de cesta

# %%
# Definindo função que fornece a quantidade e os valores único de cada feature de um dataframe
def get_values_unique(df):
    """"
    Função que, fornecido um DataFrame, printa a quantidade de valores
    únicos e os valores únicos de cada feature.

    In: DataFrame.

    Out: Print da quantidade e valores únicos da feature.
    """
    for column in df.columns:
        print(f'{column} possui {df[column].nunique()} valores únicos:')
        print(f'\n{df[column].unique()}')
        print('\n*********************************************\n')

# %% [markdown]
# ## 1 - Aquisição dos dados

# %% [markdown]
# ### a) Carregamento das bases de dados

# %%
# Lê arquivos ----------------------------------------------------------------------------
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-bc7dfd5603c6> in <cell line: 3>()
#       1 # Lê arquivos ----------------------------------------------------------------------------
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# ### b) Visualização dos DataFrames e suas informações

# %% [markdown]
# ### c) Visualização dos valores únicos dos DataFrames

# %%
# Visualizando valores únicos das features de df_vendas
get_values_unique(df_vendas)

# %%
# Visualizando valores únicos das features de df_previs
get_values_unique(df_previs)

# %% [markdown]
# ### Pontos sobre a análise inicial dos dados.

# %% [markdown]
# Tendências no mercado calçadista:
#
# Sustentabilidade: Há uma crescente demanda por calçados produzidos de forma sustentável, com materiais recicláveis ou de origem responsável. Os consumidores estão mais conscientes sobre as questões ambientais e buscam opções ecologicamente corretas.
# Conforto e funcionalidade: Os consumidores têm dado preferência a calçados que oferecem conforto, suporte e durabilidade. Calçados com tecnologias inovadoras, como solados ergonômicos e materiais respiráveis, têm ganhado destaque.
# Customização: A personalização de calçados tem se tornado uma tendência relevante, permitindo que os consumidores criem produtos únicos de acordo com suas preferências e estilo.

# %% [markdown]
# Fatores de impacto:
#
# Economia: O desempenho econômico do país tem um impacto significativo no mercado calçadista. Em momentos de recessão, por exemplo, as vendas podem diminuir devido à redução do poder de compra dos consumidores.
# Moda e estilo: Tendências de moda e estilo influenciam a demanda por calçados. A indústria deve estar atenta às preferências e mudanças de comportamento dos consumidores para se adaptar e oferecer produtos atualizados.
# Custo dos materiais: O preço e a disponibilidade de matérias-primas, como couro, borracha e tecidos, afetam diretamente os custos de produção e, consequentemente, os preços dos calçados.
#
# Concorrência internacional: A competição com produtos importados, especialmente da Ásia, é um desafio para a indústria calçadista brasileira. As diferenças de custo de produção e acordos comerciais podem impactar a competitividade dos calçados nacionais.

# %% [markdown]
# _"O ano de 2020 foi marcado pela pandemia, resultando em uma queda de 18,4% na produção
# brasileira de calçados. A indústria calçadista foi impactada por meio de diversos vetores. Um
# levantamento realizado pela Abicalçados em fevereiro de 2021 sobre a percepção das empresas
# quanto aos impactos da Covid-19 nos seus negócios destacou que, em 2020, o fechamento do
# comércio, a queda do faturamento e a redução da demanda foram os principais vetores de impactos da pandemia sobre a indústria calçadista."_

# %% [markdown]
# _Informações Adicionais:_
#
# * _Brasil está no TOP 5 produtores mundiais_
# * _Mulheres dominam o mercado calçadista (70% dele)_

# %% [markdown]
# ## 2 - Análise Exploratório dos Dados

# %%
#Qual é o total de vendas por mês?
vendas_mensais = pd.read_csv(r'/content/drive/MyDrive/VAI_SHOES/dados/tbl_vendas_mensais.csv', sep=';')

# %% [markdown]
# _A base de dados vai de Jan/2019 a Mar/2023_

# %%
vendas_mensais['vl_sale_price'] = vendas_mensais['vl_sale_price'].apply(lambda x: float(str(x).replace(',', '.')))

# %% [markdown]
# _Houve um possivel erro ao carregar os dados de Novembro de 2021, os dados estão duplicados mas com valores de vendas diferentes, para contornar esse problema, vamos utilizar a média entre os dois valores_

# %%
vendas_mensais = vendas_mensais.groupby(['dt_sale','id_sku','ds_sku','ds_category','ds_product_line','ds_brand_segment','ds_tecnology']).mean().reset_index()
sop = sop.groupby(['dt_sale','ds_product_line']).mean().reset_index()

# %% [markdown]
# _Algumas datas possuem formatação diferente, então para realizar seu tratamento, primeiro vamos transforma-las em data e depois mudar o formato com que elas são exibidas. Como os dados são mensais, vamos deixar a formatação com o primeiro dia do mês, o mês correspondente e o ano_

# %%
vendas_mensais.head(2)

# %% [markdown]
# _Procurando por valores nulos, encontramos que a coluna "vl_sale_price" possui 24 valores nulos, para tentar justificar a presença desses valores vamos investigar para avaliar o tipo de tratamento que será utilizado

# %% [markdown]
# Coluna | Valores nulos
# :---: | :---:
# vl_sale_price | 24

# %% [markdown]
# _Encontramos que os dados vazios correspondem a 2 produtos: NYC Wave e NYC Sub. Que pertencem a mesma categoria, linha, marca e usam a mesma tecnologia. Possivelmente são 2 produtos que foram adicionados recentemente a base de dados da empresa (Abril de 2022)_

# %% [markdown]
# _Encontramos que os dados vazios correspondem a 2 produtos: NYC Wave e NYC Sub. Que pertencem a mesma categoria, linha, marca e usam a mesma tecnologia. Possivelmente são 2 produtos que foram adicionados recentemente a base de dados da empresa (Abril de 2022)_

# %%
vendas_mensais[vendas_mensais.vl_sale_price.isnull()][['id_sku', 'ds_sku', 'ds_category', 'ds_product_line',
       'ds_brand_segment', 'ds_tecnology']].drop_duplicates()

# %%
gera_vl_vazios = vendas_mensais.\
  query('ds_category=="NYCs Shoes" and ds_product_line=="Shoes" and ds_brand_segment=="Core" and ds_tecnology=="LiteWeave"').\
  dropna()

gera_vl_vazios['unit_price'] = gera_vl_vazios['vl_sale_price']/gera_vl_vazios['qt_sale']

# %%
px.line(gera_vl_vazios, x='dt_sale', y='unit_price')

# %% [markdown]
# _Como o preço desse conjunto permanece constante no periodo em que esses 2 produtos foram inclusos na base, vamos selecionar os dados que correspondem a média do preço dos produtos da mesma classe e utiliza-los para preencher os valores vazios_

# %%
preco_novos_calcados = gera_vl_vazios.query("dt_sale >= '2022-04-01'").unit_price.mean()

# %%
vendas_mensais['vl_sale_price'] = vendas_mensais.apply(lambda x: x['qt_sale'] * preco_novos_calcados if pd.isna(x['vl_sale_price']) else x['vl_sale_price'], axis=1)

# %% [markdown]
# _Outro problema observado na base de dados é a questão das classes **SNEARKER**  e **SNEAKERS**, que representam o mesmo grupo. Então para corrigir esse problema vamos uni-los_

# %%
fig = px.bar(vendas_mensais.groupby(vendas_mensais['dt_sale'].dt.year).agg({'qt_sale':'sum'}).reset_index(),\
              x='dt_sale', y='qt_sale')

fig.update_layout(xaxis_title="Período", yaxis_title="QTD. Vendida", title='Vendas Anuais')

fig.show()

# %%
fig = px.bar(vendas_mensais.groupby(vendas_mensais['dt_sale'].dt.year).agg({'vl_sale_price':'sum'}).reset_index(),\
              x='dt_sale', y='vl_sale_price')

fig.update_layout(xaxis_title="Período",  title='Faturamento Anual', yaxis_title='Vendas')

fig.show()

# %%
#Analisando a série temporal como um todo
fig = px.line(vendas_mensais.groupby('dt_sale').agg({'qt_sale':'sum'}).reset_index(),\
              x='dt_sale', y='qt_sale')

fig.update_layout(xaxis_title="Período", yaxis_title="QTD. Vendida")

fig.show()

# %%
#Agora analisando as series de cada uma das classes de produtos
fig = px.line(vendas_mensais.groupby([vendas_mensais.dt_sale, 'ds_product_line']).agg({'qt_sale':'sum'}).reset_index(),\
              x='dt_sale', y='qt_sale', color='ds_product_line')

fig.update_layout(xaxis_title="Período", yaxis_title="QTD. Vendida")

fig.show()

# %%
fig = px.line(vendas_mensais.groupby([vendas_mensais.dt_sale, 'ds_sku']).agg({'unit_price':'mean'}).reset_index(),\
              x='dt_sale', y='unit_price', color='ds_sku')

fig.update_layout(xaxis_title="Período", yaxis_title="Preço", title='Preço médio por produto')

fig.show()

# %%
fig = px.bar(vendas_mensais.groupby(['ds_sku']).agg({'qt_sale':'sum'}).reset_index().sort_values('qt_sale', ascending=False),\
              x='ds_sku', y='qt_sale', color='ds_sku')

fig.update_layout(xaxis_title="Período", yaxis_title="Quantidade", title='Quantidade de produtos vendidos')

fig.show()

# %%
#Observa-se que os produtos mais vendidos são: Machina Metal, Max e Nautical Classic
fig = px.bar(vendas_mensais.groupby(['ds_sku']).agg({'vl_sale_price':'sum'}).reset_index().sort_values('vl_sale_price', ascending=False),\
              x='ds_sku', y='vl_sale_price', color='ds_sku')

fig.update_layout(xaxis_title="Período", yaxis_title="Vendas", title='Vendas Geradas')

fig.show()

# %% [markdown]
# _Quando olhamos as vendas o produto que gera maior capital é o Machina (TOP 1) seguido do Nautical Classic (TOP 3) por ultimo o Classic (TOP 5)_
#
# _O preço unitário médio de cada classe apresenta flutu_
#
# _Agora vamos realizar uma análise estatística dos dados_

# %%
data = vendas_mensais.groupby(['dt_sale']).agg({'qt_sale':'sum'}).reset_index().qt_sale

# Calcule os valores de ACF e PACF
lags = 12
acf_values = acf(data, nlags=lags)
pacf_values = pacf(data, nlags=lags)

# Crie os gráficos ACF e PACF como scatter plots com linhas individuais
fig_acf = go.Figure(data=[
    go.Scatter(x=np.arange(len(acf_values)), y=acf_values, mode='markers', name='ACF'),
])

for i in range(len(acf_values)):
    fig_acf.add_shape(type='line',
                      x0=i, y0=acf_values[i],
                      x1=i, y1=0,
                      line=dict(color='black', width=1))
fig_acf.add_shape(
    type='line',
    x0=0, y0=-0.5,
    x1=len(acf_values), y1=-0.5,
    line=dict(color='red', width=1, dash='dash')
)

fig_acf.add_shape(
    type='line',
    x0=0, y0=0.5,
    x1=len(acf_values), y1=0.5,
    line=dict(color='red', width=1, dash='dash'))

fig_acf.update_layout(
    title="Autocorrelation Function (ACF)",
    xaxis_title="Lag",
    yaxis_title="ACF Value"
)

fig_pacf = go.Figure(data=[
    go.Scatter(x=np.arange(len(pacf_values)), y=pacf_values, mode='markers', name='PACF'),
])

for i in range(len(pacf_values)):
    fig_pacf.add_shape(type='line',
                       x0=i, y0=pacf_values[i],
                       x1=i, y1=0,
                       line=dict(color='black', width=1))
fig_pacf.add_shape(
    type='line',
    x0=0, y0=-0.25,
    x1=len(acf_values), y1=-0.25,
    line=dict(color='red', width=1, dash='dash')
)

fig_pacf.add_shape(
    type='line',
    x0=0, y0=0.25,
    x1=len(acf_values), y1=0.25,
    line=dict(color='red', width=1, dash='dash'))

fig_pacf.update_layout(
    title="Partial Autocorrelation Function (PACF)",
    xaxis_title="Lag",
    yaxis_title="PACF Value"
)

# Exiba os gráficos
fig_acf.show()
fig_pacf.show()

# %% [markdown]
# _Pelo grafico ACF podemos observar que nosso problema se trata de uma serie temporal não estacionária que possui autocorrelação. Além disso, ele reforça a ideia da sazonalidade_
#
# _Como os spikes do gráfico PACF (Partial Autocorrelate Function) ultrapassam o intervalo demarcado, isso indica que a série possue autocorrelação e é não estacionária. Outro indicativo de que a série é autocorrelacionada é a presença de uma queda suave no gráfico ACF(Autocorrelate Function)_

# %%
data = vendas_mensais.groupby(['dt_sale']).agg({'qt_sale':'sum'}).reset_index()
data = data.set_index('dt_sale')
decomposition = seasonal_decompose(data['qt_sale'], model='additive', period=12)

fig = make_subplots(rows=4, cols=1, shared_xaxes=True)

# Criação dos gráficos separados para cada componente
fig = make_subplots(rows=4, cols=1, shared_xaxes=True)

# Série temporal
fig.add_trace(go.Scatter(x=data.index, y=data['qt_sale'], name='Série Temporal'), row=1, col=1)
fig.update_yaxes(title_text='Quantidade Vendida', row=1, col=1)

# Sazonalidade
fig.add_trace(go.Scatter(x=data.index, y=decomposition.seasonal, name='Sazonalidade'), row=2, col=1)
fig.update_yaxes(title_text='Sazonalidade', row=2, col=1)

# Tendência
fig.add_trace(go.Scatter(x=data.index, y=decomposition.trend, name='Tendência'), row=3, col=1)
fig.update_yaxes(title_text='Tendência', row=3, col=1)

# Resíduos
fig.add_trace(go.Scatter(x=data.index, y=decomposition.resid,mode='markers', marker=dict(color='purple'), name='Resíduos'), row=4, col=1)
fig.update_yaxes(title_text='Resíduos', row=4, col=1)

fig.update_layout(height=800, title_text='Decomposição da Série Temporal')

fig.show()

# %% [markdown]
# _Nosso problema se baseia em uma série temporal com tendência positiva e observa-se a presença de uma sazonalidade. Em relação aos residuos, os mesmo apresentam média zero, distribuição proxima a normalidade, ainda precisa avaliar a questão da homocedasticidade_

# %%
# Gerar a função KDE
kde_x = np.linspace(decomposition.resid.min(), decomposition.resid.max(), 100)
media = np.nanmean(decomposition.resid)
residuos_preenchidos = [valor if np.isfinite(valor) else media for valor in decomposition.resid]
kde_y = gaussian_kde(residuos_preenchidos)(kde_x)*30

# Criar o histograma com a função KDE
fig = go.Figure()
fig.add_trace(go.Histogram(x=decomposition.resid, histnorm='density', name='Histograma'))
fig.add_trace(go.Scatter(x=kde_x, y=kde_y, mode='lines', name='KDE'))

# Atualizar o layout do gráfico
fig.update_layout(
    title="Histograma com KDE",
    xaxis_title="Valores",
    yaxis_title="Densidade"
)

# Exibir o gráfico
fig.show()

# %% [markdown]
# ## 3 - Limpeza e pré-processamento de dados

# %%
# Importando os dados
df = pd.read_csv('/content/tbl_vendas_mensais.csv', sep=';')

# Converte a coluna 'dt_sale' para tipo datetime.
# Joga fora as colunas não relevantes
# Converte a categoria de Sneaker para Sneakers
df['dt_sale'] = pd.to_datetime(df['dt_sale'], utc=True)
df.drop(columns=['ds_sku', 'ds_category', 'ds_brand_segment', 'ds_tecnology', 'vl_sale_price'], inplace=True)
df.loc[df['ds_product_line'] == 'Sneaker', 'ds_product_line'] = 'Sneakers'

# Faz a média nos valores de novembro de 2021
df_novembro_2021 = df[df['dt_sale'] == '2021-11']
df_novembro_2021 = df_novembro_2021.groupby(['id_sku', 'ds_product_line', 'dt_sale']).mean()
df_novembro_2021.reset_index(inplace=True)
df_novembro_2021 = df_novembro_2021.set_index('dt_sale')

# Remove os valores antigos de novembro de 2021 e adiciona os novos
df.drop(index=df[df['dt_sale'] == '2021-11'].index, inplace=True)
df.set_index('dt_sale', drop=True, inplace=True)
df = pd.concat([df, df_novembro_2021])
df.drop(columns='id_sku', inplace=True)
df.sort_index(inplace=True)

# Retorna o dataset final. Para cada produto('ds_product_line') temos a quantidade total de vendas.
df = df.groupby(['dt_sale', 'ds_product_line']).sum()
df.reset_index(inplace=True)
df
# Out:
#                       dt_sale ds_product_line   qt_sale
# 0   2019-01-01 00:00:00+00:00            Boot  191839.0
# 1   2019-01-01 00:00:00+00:00         Sandals  311140.0
# 2   2019-01-01 00:00:00+00:00           Shoes  575501.0
# 3   2019-01-01 00:00:00+00:00        Sneakers  279316.0
# 4   2019-02-01 00:00:00+00:00            Boot  214879.0
# ..                        ...             ...       ...
# 199 2023-02-01 00:00:00+00:00        Sneakers  511301.0
# 200 2023-03-01 00:00:00+00:00            Boot  184398.0
# 201 2023-03-01 00:00:00+00:00         Sandals  481353.0
# 202 2023-03-01 00:00:00+00:00           Shoes  812154.0
# 203 2023-03-01 00:00:00+00:00        Sneakers  441090.0
#
# [204 rows x 3 columns]

# %% [markdown]
# # **4 - Implementação dos Modelos**

# %% [markdown]
# ## **Rede Neural Recorrente (arquitetura LSTM)**

# %%
df = df.loc[:, ['dt_sale', 'ds_product_line', 'qt_sale']]

tbl = df.groupby(['dt_sale', 'ds_product_line']).sum()
tbl = tbl.sort_values(by='dt_sale')
tbl = tbl.reset_index()

#Separando o Df de cada categoria
df_Boot = tbl[tbl['ds_product_line'] == 'Boot']
df_Sandals = tbl[tbl['ds_product_line'] == 'Sandals']
df_Shoes = tbl[tbl['ds_product_line'] == 'Shoes']
df_Sneakers = tbl[tbl['ds_product_line'] == 'Sneakers']

# %%
#Função que separa os atributos previsores para treinamento da rede neural
def Sepacao_previsores(df):
    df_treino = df.iloc[:47,:]

    #Escalonando
    df_treino = df_treino['qt_sale'].values
    df_treino = df_treino.reshape(-1, 1)
    escaler = StandardScaler()
    df_treino_escalonada = escaler.fit_transform(df_treino)

    previsores = []
    qt_real = []

    #Para a previsão de um dia, nesse caso, são necessários analisar os 12 meses anteriores
    for i in range(12, len(df_treino)):
        previsores.append(df_treino_escalonada[i - 12:i, 0])
        qt_real.append(df_treino_escalonada[i, 0])

    #Reformatação para a forma requerida pelo KERAS
    previsores, qt_real = np.array(previsores), np.array(qt_real)
    previsores = np.reshape(previsores, (previsores.shape[0], previsores.shape[1], 1))
    return previsores, qt_real, escaler

# %%
#Função que aplica a rede neural
def RNN(previsores, qt_real):
    #Arquitetura da rede neural
    regressor = Sequential()
    regressor.add(LSTM(units=100, return_sequences=True, input_shape=(previsores.shape[1], 1)))
    regressor.add(Dropout(0.3)) #Irá zerar 30% das entradas (Ajuda a previnir overfitting)

    regressor.add(LSTM(units=40, return_sequences=True))
    regressor.add(Dropout(0.3))

    regressor.add(LSTM(units=50, return_sequences=True))
    regressor.add(Dropout(0.3))

    regressor.add(LSTM(units=60, return_sequences=False))
    regressor.add(Dropout(0.2))

    #Camada de saída
    regressor.add(Dense(units= 1, activation='linear'))

    regressor.compile(optimizer='rmsprop', loss='mean_squared_error', metrics = ['mean_absolute_error'])

    #mc = ModelCheckpoint('Best_weights.h5', save_best_only=True, monitor='loss', verbose=1) #Salva os melhores pesos da RN

    regressor.fit(previsores, qt_real, epochs=200, batch_size=12)
    return regressor

# %%
#função que a partir do modelo treinado cria por meio de condicionais as colunas m1, m2 e m3
def Previsões(df, regressor, escaler):
    m1 = []
    m2 = []
    m3 = []
    #Ciclo que vai de setembro até fevereiro
    for i in range(45, 51):
        #Previsão de Setembro
        if i == 45:
            df_teste = df.iloc[i,:]
            df_B = df['qt_sale']
            entradas = df_B[i - 12:i].values
            entradas = entradas.reshape(-1, 1)
            entradas = escaler.transform(entradas)

            for a in range(0, 3):
                X_teste = []
                X_teste.append(entradas[0: 12, 0])
                X_teste = np.array(X_teste)
                X_teste = np.reshape(X_teste, (X_teste.shape[0], X_teste.shape[1], 1))
                prev = regressor.predict(X_teste)

                if a == 2:
                    prev = escaler.inverse_transform(prev)
                    m3.append(float(prev))
                entradas = np.delete(entradas, 0, axis=0) #Retro alimentação, excluindo o primeiro...
                entradas = np.insert(entradas, entradas.shape[0], [prev],axis= 0) #E adicionando a previsão com ultimo
        #Previsão de Outubro
        if i == 46:
            df_teste = df.iloc[i,:]
            df_B = df['qt_sale']
            entradas = df_B[i - 12:i].values
            entradas = entradas.reshape(-1, 1)
            entradas = escaler.transform(entradas)

            for a in range(0, 3):
                X_teste = []
                X_teste.append(entradas[0: 12, 0])
                X_teste = np.array(X_teste)
                X_teste = np.reshape(X_teste, (X_teste.shape[0], X_teste.shape[1], 1))
                prev = regressor.predict(X_teste)

                if a == 1: #M - 2
                   prev_inverse = escaler.inverse_transform(prev)
                   m2.append(float(prev_inverse))
                if a == 2: #M - 3
                    prev = escaler.inverse_transform(prev)
                    m3.append(float(prev))
                entradas = np.delete(entradas, 0, axis=0)
                entradas = np.insert(entradas, entradas.shape[0], [prev],axis= 0)
        #Previsão de Novembro
        if i == 47:
            df_teste = df.iloc[i,:]
            df_B = df['qt_sale']
            entradas = df_B[i - 12:i].values
            entradas = entradas.reshape(-1, 1)
            entradas = escaler.transform(entradas)

            for a in range(0, 3):
                X_teste = []
                X_teste.append(entradas[0: 12, 0])
                X_teste = np.array(X_teste)
                X_teste = np.reshape(X_teste, (X_teste.shape[0], X_teste.shape[1], 1))
                prev = regressor.predict(X_teste)

                if a == 0: #M - 1
                   prev_inverse = escaler.inverse_transform(prev)
                   m1.append(float(prev_inverse))
                if a == 1: #M - 2
                   prev_inverse = escaler.inverse_transform(prev)
                   m2.append(float(prev_inverse))
                if a == 2: #M - 3
                    prev = escaler.inverse_transform(prev)
                    m3.append(float(prev))
                entradas = np.delete(entradas, 0, axis=0)
                entradas = np.insert(entradas, entradas.shape[0], [prev],axis= 0)
        #Previsão de Dezembro
        if i == 48:
            df_teste = df.iloc[i,:]
            df_B = df['qt_sale']
            entradas = df_B[i - 12:i].values
            entradas = entradas.reshape(-1, 1)
            entradas = escaler.transform(entradas)

            for a in range(0, 3):
                X_teste = []
                X_teste.append(entradas[0: 12, 0])
                X_teste = np.array(X_teste)
                X_teste = np.reshape(X_teste, (X_teste.shape[0], X_teste.shape[1], 1))
                prev = regressor.predict(X_teste)

                if a == 0: #M - 1
                   prev_inverse = escaler.inverse_transform(prev)
                   m1.append(float(prev_inverse))
                if a == 1: #M - 2
                   prev_inverse = escaler.inverse_transform(prev)
                   m2.append(float(prev_inverse))
                if a == 2: #M - 3
                    prev = escaler.inverse_transform(prev)
                    m3.append(float(prev))
                entradas = np.delete(entradas, 0, axis=0)
                entradas = np.insert(entradas, entradas.shape[0], [prev],axis= 0)
        #Previsão de Janeiro
        if i == 49:
            df_teste = df.iloc[i,:]
            df_B = df['qt_sale']
            entradas = df_B[i - 12:i].values
            entradas = entradas.reshape(-1, 1)
            entradas = escaler.transform(entradas)

            for a in range(0, 3):
                X_teste = []
                X_teste.append(entradas[0: 12, 0])
                X_teste = np.array(X_teste)
                X_teste = np.reshape(X_teste, (X_teste.shape[0], X_teste.shape[1], 1))
                prev = regressor.predict(X_teste)

                if a == 0: #M - 1
                   prev_inverse = escaler.inverse_transform(prev)
                   m1.append(float(prev_inverse))
                if a == 1: #M - 2
                   prev_inverse = escaler.inverse_transform(prev)
                   m2.append(float(prev_inverse))

                entradas = np.delete(entradas, 0, axis=0)
                entradas = np.insert(entradas, entradas.shape[0], [prev],axis= 0)
        #Previsão de Fevereiro
        if i == 50:
            df_teste = df.iloc[i,:]
            df_B = df['qt_sale']
            entradas = df_B[i - 12:i].values
            entradas = entradas.reshape(-1, 1)
            entradas = escaler.transform(entradas)

            for a in range(0, 3):
                X_teste = []
                X_teste.append(entradas[0: 12, 0])
                X_teste = np.array(X_teste)
                X_teste = np.reshape(X_teste, (X_teste.shape[0], X_teste.shape[1], 1))
                prev = regressor.predict(X_teste)

                if a == 0: #M - 1
                   prev_inverse = escaler.inverse_transform(prev)
                   m1.append(float(prev_inverse))

                entradas = np.delete(entradas, 0, axis=0)
                entradas = np.insert(entradas, entradas.shape[0], [prev],axis= 0)

    Product = df.iloc[47:]

    Product['Previsão_M1'] = m1
    Product['Previsão_M2'] = m2
    Product['Previsão_M3'] = m3
    return Product

# %%
#Chamado das funções e geração das tabelas de previsão
previsores, qt_real, escaler = Sepacao_previsores(df_Boot)
Boot = Previsões(df_Boot, RNN(previsores, qt_real), escaler)

previsores, qt_real, escaler = Sepacao_previsores(df_Sandals)
Sandals = Previsões(df_Sandals, RNN(previsores, qt_real), escaler)

previsores, qt_real, escaler = Sepacao_previsores(df_Shoes)
Shoes = Previsões(df_Shoes, RNN(previsores, qt_real), escaler)

previsores, qt_real, escaler = Sepacao_previsores(df_Sneakers)
Sneakers = Previsões(df_Sneakers, RNN(previsores, qt_real), escaler)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 11s 51ms/step - loss: 1.0051 - mean_absolute_error: 0.8580
# Epoch 2/200
# 3/3 [==============================] - 0s 62ms/step - loss: 0.9873 - mean_absolute_error: 0.8591
# Epoch 3/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.9429 - mean_absolute_error: 0.8416
# Epoch 4/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.9700 - mean_absolute_error: 0.8617
# Epoch 5/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.9363 - mean_absolute_error: 0.8422
# Epoch 6/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.9657 - mean_absolute_error: 0.8657
# Epoch 7/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.9180 - mean_absolute_error: 0.8375
# Epoch 8/200
# 3/3 [==============================] - 0s 49ms/step - loss: 0.9059 - mean_absolute_error: 0.8333
# Epoch 9/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.8883 - mean_absolute_error: 0.8270
# Epoch 10/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8634 - mean_absolute_error: 0.8262
# Epoch 11/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7592 - mean_absolute_error: 0.7696
# Epoch 12/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.7816 - mean_absolute_error: 0.7935
# Epoch 13/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5812 - mean_absolute_error: 0.6233
# Epoch 14/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5067 - mean_absolute_error: 0.5876
# Epoch 15/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5003 - mean_absolute_error: 0.5750
# Epoch 16/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.4626 - mean_absolute_error: 0.5808
# Epoch 17/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.4147 - mean_absolute_error: 0.5347
# Epoch 18/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5581 - mean_absolute_error: 0.6091
# Epoch 19/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5918 - mean_absolute_error: 0.6443
# Epoch 20/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.4036 - mean_absolute_error: 0.5392
# Epoch 21/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.4168 - mean_absolute_error: 0.5527
# Epoch 22/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4809 - mean_absolute_error: 0.5620
# Epoch 23/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3476 - mean_absolute_error: 0.5145
# Epoch 24/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.4077 - mean_absolute_error: 0.5268
# Epoch 25/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5220 - mean_absolute_error: 0.5655
# Epoch 26/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.3527 - mean_absolute_error: 0.4943
# Epoch 27/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3933 - mean_absolute_error: 0.5434
# Epoch 28/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.3332 - mean_absolute_error: 0.5096
# Epoch 29/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4033 - mean_absolute_error: 0.5100
# Epoch 30/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.4969 - mean_absolute_error: 0.6054
# Epoch 31/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.3848 - mean_absolute_error: 0.5009
# Epoch 32/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5035 - mean_absolute_error: 0.6247
# Epoch 33/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.3649 - mean_absolute_error: 0.5150
# Epoch 34/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4015 - mean_absolute_error: 0.5214
# Epoch 35/200
# 3/3 [==============================] - 0s 75ms/step - loss: 0.3464 - mean_absolute_error: 0.4802
# Epoch 36/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3994 - mean_absolute_error: 0.5373
# Epoch 37/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.4431 - mean_absolute_error: 0.5560
# Epoch 38/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.3619 - mean_absolute_error: 0.4911
# Epoch 39/200
# 3/3 [==============================] - 0s 68ms/step - loss: 0.3810 - mean_absolute_error: 0.5263
# Epoch 40/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.4129 - mean_absolute_error: 0.5383
# Epoch 41/200
# 3/3 [==============================] - 0s 114ms/step - loss: 0.3103 - mean_absolute_error: 0.4687
# Epoch 42/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3308 - mean_absolute_error: 0.4507
# Epoch 43/200
# 3/3 [==============================] - 0s 71ms/step - loss: 0.4081 - mean_absolute_error: 0.5480
# Epoch 44/200
# 3/3 [==============================] - 0s 77ms/step - loss: 0.3348 - mean_absolute_error: 0.4671
# Epoch 45/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.3571 - mean_absolute_error: 0.4891
# Epoch 46/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.3789 - mean_absolute_error: 0.5220
# Epoch 47/200
# 3/3 [==============================] - 0s 68ms/step - loss: 0.4202 - mean_absolute_error: 0.5270
# Epoch 48/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3474 - mean_absolute_error: 0.4855
# Epoch 49/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3454 - mean_absolute_error: 0.4841
# Epoch 50/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3193 - mean_absolute_error: 0.4492
# Epoch 51/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3467 - mean_absolute_error: 0.4655
# Epoch 52/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3242 - mean_absolute_error: 0.4523
# Epoch 53/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3229 - mean_absolute_error: 0.4618
# Epoch 54/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3861 - mean_absolute_error: 0.4833
# Epoch 55/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3488 - mean_absolute_error: 0.4817
# Epoch 56/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2869 - mean_absolute_error: 0.4457
# Epoch 57/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3149 - mean_absolute_error: 0.4303
# Epoch 58/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3780 - mean_absolute_error: 0.4896
# Epoch 59/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2838 - mean_absolute_error: 0.4371
# Epoch 60/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3728 - mean_absolute_error: 0.4821
# Epoch 61/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2834 - mean_absolute_error: 0.4188
# Epoch 62/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2535 - mean_absolute_error: 0.4108
# Epoch 63/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3311 - mean_absolute_error: 0.4684
# Epoch 64/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3249 - mean_absolute_error: 0.4380
# Epoch 65/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.4138 - mean_absolute_error: 0.5004
# Epoch 66/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3222 - mean_absolute_error: 0.4304
# Epoch 67/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2954 - mean_absolute_error: 0.4415
# Epoch 68/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3345 - mean_absolute_error: 0.4510
# Epoch 69/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2996 - mean_absolute_error: 0.4473
# Epoch 70/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2927 - mean_absolute_error: 0.4300
# Epoch 71/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3424 - mean_absolute_error: 0.4688
# Epoch 72/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3216 - mean_absolute_error: 0.4416
# Epoch 73/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.3194 - mean_absolute_error: 0.4583
# Epoch 74/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2927 - mean_absolute_error: 0.4293
# Epoch 75/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3610 - mean_absolute_error: 0.4807
# Epoch 76/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3163 - mean_absolute_error: 0.4626
# Epoch 77/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3235 - mean_absolute_error: 0.4373
# Epoch 78/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3226 - mean_absolute_error: 0.4469
# Epoch 79/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3003 - mean_absolute_error: 0.4409
# Epoch 80/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3296 - mean_absolute_error: 0.4769
# Epoch 81/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2542 - mean_absolute_error: 0.4173
# Epoch 82/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2875 - mean_absolute_error: 0.4253
# Epoch 83/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3360 - mean_absolute_error: 0.4769
# Epoch 84/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3115 - mean_absolute_error: 0.4153
# Epoch 85/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3207 - mean_absolute_error: 0.4369
# Epoch 86/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2739 - mean_absolute_error: 0.4096
# Epoch 87/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.3010 - mean_absolute_error: 0.4423
# Epoch 88/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2878 - mean_absolute_error: 0.4182
# Epoch 89/200
# 3/3 [==============================] - 0s 51ms/step - loss: 0.2796 - mean_absolute_error: 0.4242
# Epoch 90/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.3571 - mean_absolute_error: 0.4910
# Epoch 91/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.3072 - mean_absolute_error: 0.4355
# Epoch 92/200
# 3/3 [==============================] - 0s 57ms/step - loss: 0.3621 - mean_absolute_error: 0.4962
# Epoch 93/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.3333 - mean_absolute_error: 0.4732
# Epoch 94/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.3559 - mean_absolute_error: 0.4731
# Epoch 95/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.2956 - mean_absolute_error: 0.4295
# Epoch 96/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.3182 - mean_absolute_error: 0.4525
# Epoch 97/200
# 3/3 [==============================] - 0s 63ms/step - loss: 0.3012 - mean_absolute_error: 0.4389
# Epoch 98/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3151 - mean_absolute_error: 0.4317
# Epoch 99/200
# 3/3 [==============================] - 0s 53ms/step - loss: 0.2781 - mean_absolute_error: 0.4167
# Epoch 100/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2787 - mean_absolute_error: 0.4247
# Epoch 101/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3211 - mean_absolute_error: 0.4585
# Epoch 102/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2658 - mean_absolute_error: 0.4042
# Epoch 103/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.2855 - mean_absolute_error: 0.4095
# Epoch 104/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.3105 - mean_absolute_error: 0.4380
# Epoch 105/200
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2757 - mean_absolute_error: 0.4113
# Epoch 106/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2603 - mean_absolute_error: 0.3884
# Epoch 107/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3357 - mean_absolute_error: 0.4644
# Epoch 108/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2977 - mean_absolute_error: 0.4007
# Epoch 109/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2182 - mean_absolute_error: 0.3666
# Epoch 110/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2959 - mean_absolute_error: 0.4207
# Epoch 111/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2600 - mean_absolute_error: 0.3940
# Epoch 112/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3110 - mean_absolute_error: 0.4444
# Epoch 113/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3145 - mean_absolute_error: 0.4601
# Epoch 114/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.3128 - mean_absolute_error: 0.4417
# Epoch 115/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2884 - mean_absolute_error: 0.4363
# Epoch 116/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2830 - mean_absolute_error: 0.3870
# Epoch 117/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2544 - mean_absolute_error: 0.3932
# Epoch 118/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2882 - mean_absolute_error: 0.4439
# Epoch 119/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2987 - mean_absolute_error: 0.4500
# Epoch 120/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2777 - mean_absolute_error: 0.4045
# Epoch 121/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2369 - mean_absolute_error: 0.3790
# Epoch 122/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2675 - mean_absolute_error: 0.3894
# Epoch 123/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2564 - mean_absolute_error: 0.3921
# Epoch 124/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3091 - mean_absolute_error: 0.4256
# Epoch 125/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2536 - mean_absolute_error: 0.3902
# Epoch 126/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2695 - mean_absolute_error: 0.3814
# Epoch 127/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2844 - mean_absolute_error: 0.4200
# Epoch 128/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2796 - mean_absolute_error: 0.4043
# Epoch 129/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2761 - mean_absolute_error: 0.4205
# Epoch 130/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2771 - mean_absolute_error: 0.4119
# Epoch 131/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2531 - mean_absolute_error: 0.3941
# Epoch 132/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2854 - mean_absolute_error: 0.4167
# Epoch 133/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2400 - mean_absolute_error: 0.3775
# Epoch 134/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2723 - mean_absolute_error: 0.3972
# Epoch 135/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2355 - mean_absolute_error: 0.3568
# Epoch 136/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2495 - mean_absolute_error: 0.4123
# Epoch 137/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2654 - mean_absolute_error: 0.3937
# Epoch 138/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2565 - mean_absolute_error: 0.4046
# Epoch 139/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2211 - mean_absolute_error: 0.3456
# Epoch 140/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2451 - mean_absolute_error: 0.3661
# Epoch 141/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2641 - mean_absolute_error: 0.3944
# Epoch 142/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2730 - mean_absolute_error: 0.4022
# Epoch 143/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2174 - mean_absolute_error: 0.3631
# Epoch 144/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2169 - mean_absolute_error: 0.3564
# Epoch 145/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2823 - mean_absolute_error: 0.4105
# Epoch 146/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2452 - mean_absolute_error: 0.3819
# Epoch 147/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2341 - mean_absolute_error: 0.3694
# Epoch 148/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2379 - mean_absolute_error: 0.3813
# Epoch 149/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2542 - mean_absolute_error: 0.3883
# Epoch 150/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2126 - mean_absolute_error: 0.3792
# Epoch 151/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2243 - mean_absolute_error: 0.3522
# Epoch 152/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2694 - mean_absolute_error: 0.3913
# Epoch 153/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1908 - mean_absolute_error: 0.3439
# Epoch 154/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3267 - mean_absolute_error: 0.4375
# Epoch 155/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2459 - mean_absolute_error: 0.3663
# Epoch 156/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2538 - mean_absolute_error: 0.4124
# Epoch 157/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2359 - mean_absolute_error: 0.3848
# Epoch 158/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2309 - mean_absolute_error: 0.3676
# Epoch 159/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2609 - mean_absolute_error: 0.4001
# Epoch 160/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2528 - mean_absolute_error: 0.3974
# Epoch 161/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2593 - mean_absolute_error: 0.3997
# Epoch 162/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2474 - mean_absolute_error: 0.3676
# Epoch 163/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2229 - mean_absolute_error: 0.3688
# Epoch 164/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1966 - mean_absolute_error: 0.3247
# Epoch 165/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2068 - mean_absolute_error: 0.3289
# Epoch 166/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2634 - mean_absolute_error: 0.3928
# Epoch 167/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1975 - mean_absolute_error: 0.3340
# Epoch 168/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3102 - mean_absolute_error: 0.4359
# Epoch 169/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1982 - mean_absolute_error: 0.3387
# Epoch 170/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2059 - mean_absolute_error: 0.3332
# Epoch 171/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1769 - mean_absolute_error: 0.3159
# Epoch 172/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1853 - mean_absolute_error: 0.3206
# Epoch 173/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1720 - mean_absolute_error: 0.3044
# Epoch 174/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2222 - mean_absolute_error: 0.3669
# Epoch 175/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2051 - mean_absolute_error: 0.3312
# Epoch 176/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1714 - mean_absolute_error: 0.3200
# Epoch 177/200
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2521 - mean_absolute_error: 0.3634
# Epoch 178/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1582 - mean_absolute_error: 0.2999
# Epoch 179/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1646 - mean_absolute_error: 0.3057
# Epoch 180/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2150 - mean_absolute_error: 0.3734
# Epoch 181/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1445 - mean_absolute_error: 0.2849
# Epoch 182/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1385 - mean_absolute_error: 0.2870
# Epoch 183/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1795 - mean_absolute_error: 0.3295
# Epoch 184/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2399 - mean_absolute_error: 0.3864
# Epoch 185/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1759 - mean_absolute_error: 0.3241
# Epoch 186/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1932 - mean_absolute_error: 0.3112
# Epoch 187/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1438 - mean_absolute_error: 0.2850
# Epoch 188/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1883 - mean_absolute_error: 0.3333
# Epoch 189/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1654 - mean_absolute_error: 0.3255
# Epoch 190/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2450 - mean_absolute_error: 0.3759
# Epoch 191/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1385 - mean_absolute_error: 0.2821
# Epoch 192/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.1920 - mean_absolute_error: 0.3302
# Epoch 193/200
# 3/3 [==============================] - 0s 51ms/step - loss: 0.1547 - mean_absolute_error: 0.3003
# Epoch 194/200
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1703 - mean_absolute_error: 0.3016
# Epoch 195/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.1628 - mean_absolute_error: 0.3044
# Epoch 196/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1489 - mean_absolute_error: 0.2980
# Epoch 197/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.1369 - mean_absolute_error: 0.2779
# Epoch 198/200
# 3/3 [==============================] - 0s 51ms/step - loss: 0.1306 - mean_absolute_error: 0.2662
# Epoch 199/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.1283 - mean_absolute_error: 0.2826
# Epoch 200/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.1791 - mean_absolute_error: 0.3332
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 28ms/step
# <ipython-input-35-2d5bc51efce8>:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Product['Previsão_M1'] = m1
# <ipython-input-35-2d5bc51efce8>:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Product['Previsão_M2'] = m2
# <ipython-input-35-2d5bc51efce8>:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Product['Previsão_M3'] = m3
# Epoch 1/200
# 3/3 [==============================] - 9s 36ms/step - loss: 0.5947 - mean_absolute_error: 0.6451
# Epoch 2/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3953 - mean_absolute_error: 0.5357
# Epoch 3/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3175 - mean_absolute_error: 0.4835
# Epoch 4/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3263 - mean_absolute_error: 0.4812
# Epoch 5/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3301 - mean_absolute_error: 0.4779
# Epoch 6/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.3613 - mean_absolute_error: 0.5010
# Epoch 7/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3073 - mean_absolute_error: 0.4707
# Epoch 8/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3105 - mean_absolute_error: 0.4722
# Epoch 9/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3355 - mean_absolute_error: 0.4968
# Epoch 10/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3394 - mean_absolute_error: 0.4963
# Epoch 11/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3308 - mean_absolute_error: 0.5026
# Epoch 12/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3313 - mean_absolute_error: 0.5015
# Epoch 13/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3367 - mean_absolute_error: 0.5017
# Epoch 14/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3304 - mean_absolute_error: 0.4866
# Epoch 15/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3561 - mean_absolute_error: 0.4970
# Epoch 16/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2961 - mean_absolute_error: 0.4634
# Epoch 17/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3230 - mean_absolute_error: 0.4816
# Epoch 18/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3161 - mean_absolute_error: 0.4937
# Epoch 19/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3004 - mean_absolute_error: 0.4686
# Epoch 20/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3444 - mean_absolute_error: 0.4806
# Epoch 21/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.3060 - mean_absolute_error: 0.4811
# Epoch 22/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3013 - mean_absolute_error: 0.4590
# Epoch 23/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2758 - mean_absolute_error: 0.4382
# Epoch 24/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3970 - mean_absolute_error: 0.5039
# Epoch 25/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3318 - mean_absolute_error: 0.4934
# Epoch 26/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3037 - mean_absolute_error: 0.4629
# Epoch 27/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3094 - mean_absolute_error: 0.4691
# Epoch 28/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3139 - mean_absolute_error: 0.4745
# Epoch 29/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3185 - mean_absolute_error: 0.4700
# Epoch 30/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3510 - mean_absolute_error: 0.4936
# Epoch 31/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3363 - mean_absolute_error: 0.4940
# Epoch 32/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3586 - mean_absolute_error: 0.5123
# Epoch 33/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3341 - mean_absolute_error: 0.4810
# Epoch 34/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2891 - mean_absolute_error: 0.4522
# Epoch 35/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3535 - mean_absolute_error: 0.5041
# Epoch 36/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3047 - mean_absolute_error: 0.4731
# Epoch 37/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2916 - mean_absolute_error: 0.4561
# Epoch 38/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3203 - mean_absolute_error: 0.4800
# Epoch 39/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3122 - mean_absolute_error: 0.4712
# Epoch 40/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3017 - mean_absolute_error: 0.4555
# Epoch 41/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3179 - mean_absolute_error: 0.4833
# Epoch 42/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2966 - mean_absolute_error: 0.4618
# Epoch 43/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3029 - mean_absolute_error: 0.4785
# Epoch 44/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.3357 - mean_absolute_error: 0.5075
# Epoch 45/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2989 - mean_absolute_error: 0.4727
# Epoch 46/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2772 - mean_absolute_error: 0.4462
# Epoch 47/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3031 - mean_absolute_error: 0.4678
# Epoch 48/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2795 - mean_absolute_error: 0.4540
# Epoch 49/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3226 - mean_absolute_error: 0.4832
# Epoch 50/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3163 - mean_absolute_error: 0.4786
# Epoch 51/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3682 - mean_absolute_error: 0.5332
# Epoch 52/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3004 - mean_absolute_error: 0.4802
# Epoch 53/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2749 - mean_absolute_error: 0.4538
# Epoch 54/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2718 - mean_absolute_error: 0.4386
# Epoch 55/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3057 - mean_absolute_error: 0.4768
# Epoch 56/200
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2771 - mean_absolute_error: 0.4367
# Epoch 57/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2995 - mean_absolute_error: 0.4561
# Epoch 58/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2734 - mean_absolute_error: 0.4536
# Epoch 59/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2973 - mean_absolute_error: 0.4727
# Epoch 60/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3188 - mean_absolute_error: 0.4800
# Epoch 61/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2512 - mean_absolute_error: 0.4220
# Epoch 62/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2808 - mean_absolute_error: 0.4502
# Epoch 63/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2795 - mean_absolute_error: 0.4541
# Epoch 64/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2569 - mean_absolute_error: 0.4331
# Epoch 65/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2711 - mean_absolute_error: 0.4376
# Epoch 66/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2953 - mean_absolute_error: 0.4528
# Epoch 67/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2969 - mean_absolute_error: 0.4478
# Epoch 68/200
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2493 - mean_absolute_error: 0.4275
# Epoch 69/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2704 - mean_absolute_error: 0.4603
# Epoch 70/200
# 3/3 [==============================] - 0s 51ms/step - loss: 0.2489 - mean_absolute_error: 0.4312
# Epoch 71/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2650 - mean_absolute_error: 0.4254
# Epoch 72/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.3053 - mean_absolute_error: 0.4535
# Epoch 73/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2492 - mean_absolute_error: 0.4416
# Epoch 74/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2916 - mean_absolute_error: 0.4638
# Epoch 75/200
# 3/3 [==============================] - 0s 53ms/step - loss: 0.2692 - mean_absolute_error: 0.4443
# Epoch 76/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.2461 - mean_absolute_error: 0.4247
# Epoch 77/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.2430 - mean_absolute_error: 0.4226
# Epoch 78/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.2377 - mean_absolute_error: 0.4209
# Epoch 79/200
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2298 - mean_absolute_error: 0.4236
# Epoch 80/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2481 - mean_absolute_error: 0.4248
# Epoch 81/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2810 - mean_absolute_error: 0.4482
# Epoch 82/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2327 - mean_absolute_error: 0.4191
# Epoch 83/200
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2516 - mean_absolute_error: 0.4449
# Epoch 84/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2152 - mean_absolute_error: 0.4073
# Epoch 85/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.2944 - mean_absolute_error: 0.4762
# Epoch 86/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2864 - mean_absolute_error: 0.4476
# Epoch 87/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.2623 - mean_absolute_error: 0.4405
# Epoch 88/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2441 - mean_absolute_error: 0.4192
# Epoch 89/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2132 - mean_absolute_error: 0.3965
# Epoch 90/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2076 - mean_absolute_error: 0.3832
# Epoch 91/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2323 - mean_absolute_error: 0.4046
# Epoch 92/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2253 - mean_absolute_error: 0.4123
# Epoch 93/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2198 - mean_absolute_error: 0.4170
# Epoch 94/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2188 - mean_absolute_error: 0.3976
# Epoch 95/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2109 - mean_absolute_error: 0.4040
# Epoch 96/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2530 - mean_absolute_error: 0.4401
# Epoch 97/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2323 - mean_absolute_error: 0.4135
# Epoch 98/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1844 - mean_absolute_error: 0.3816
# Epoch 99/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2587 - mean_absolute_error: 0.4274
# Epoch 100/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2490 - mean_absolute_error: 0.4102
# Epoch 101/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2186 - mean_absolute_error: 0.4049
# Epoch 102/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2142 - mean_absolute_error: 0.3898
# Epoch 103/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2131 - mean_absolute_error: 0.3919
# Epoch 104/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2384 - mean_absolute_error: 0.4233
# Epoch 105/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2703 - mean_absolute_error: 0.4514
# Epoch 106/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1946 - mean_absolute_error: 0.3961
# Epoch 107/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2199 - mean_absolute_error: 0.3988
# Epoch 108/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1987 - mean_absolute_error: 0.3741
# Epoch 109/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2129 - mean_absolute_error: 0.4062
# Epoch 110/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2147 - mean_absolute_error: 0.3985
# Epoch 111/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2215 - mean_absolute_error: 0.3889
# Epoch 112/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2322 - mean_absolute_error: 0.4087
# Epoch 113/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2141 - mean_absolute_error: 0.4078
# Epoch 114/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2204 - mean_absolute_error: 0.4059
# Epoch 115/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2067 - mean_absolute_error: 0.3915
# Epoch 116/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1900 - mean_absolute_error: 0.3639
# Epoch 117/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1737 - mean_absolute_error: 0.3512
# Epoch 118/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1684 - mean_absolute_error: 0.3462
# Epoch 119/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1925 - mean_absolute_error: 0.3795
# Epoch 120/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1950 - mean_absolute_error: 0.3520
# Epoch 121/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1713 - mean_absolute_error: 0.3577
# Epoch 122/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2126 - mean_absolute_error: 0.4000
# Epoch 123/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1825 - mean_absolute_error: 0.3750
# Epoch 124/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1767 - mean_absolute_error: 0.3627
# Epoch 125/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2203 - mean_absolute_error: 0.3782
# Epoch 126/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2125 - mean_absolute_error: 0.3916
# Epoch 127/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1657 - mean_absolute_error: 0.3541
# Epoch 128/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2125 - mean_absolute_error: 0.3970
# Epoch 129/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1814 - mean_absolute_error: 0.3591
# Epoch 130/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1612 - mean_absolute_error: 0.3307
# Epoch 131/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1701 - mean_absolute_error: 0.3585
# Epoch 132/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2041 - mean_absolute_error: 0.3742
# Epoch 133/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1811 - mean_absolute_error: 0.3694
# Epoch 134/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1549 - mean_absolute_error: 0.3223
# Epoch 135/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1669 - mean_absolute_error: 0.3554
# Epoch 136/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1684 - mean_absolute_error: 0.3434
# Epoch 137/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1645 - mean_absolute_error: 0.3568
# Epoch 138/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1860 - mean_absolute_error: 0.3880
# Epoch 139/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1629 - mean_absolute_error: 0.3403
# Epoch 140/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1487 - mean_absolute_error: 0.3253
# Epoch 141/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1571 - mean_absolute_error: 0.3467
# Epoch 142/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1460 - mean_absolute_error: 0.3270
# Epoch 143/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1686 - mean_absolute_error: 0.3552
# Epoch 144/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1775 - mean_absolute_error: 0.3682
# Epoch 145/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1772 - mean_absolute_error: 0.3612
# Epoch 146/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1496 - mean_absolute_error: 0.3118
# Epoch 147/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1569 - mean_absolute_error: 0.3416
# Epoch 148/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1524 - mean_absolute_error: 0.3112
# Epoch 149/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1836 - mean_absolute_error: 0.3778
# Epoch 150/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2106 - mean_absolute_error: 0.3890
# Epoch 151/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1575 - mean_absolute_error: 0.3502
# Epoch 152/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1436 - mean_absolute_error: 0.3293
# Epoch 153/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1574 - mean_absolute_error: 0.3242
# Epoch 154/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1381 - mean_absolute_error: 0.3053
# Epoch 155/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1540 - mean_absolute_error: 0.3344
# Epoch 156/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1598 - mean_absolute_error: 0.3557
# Epoch 157/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1705 - mean_absolute_error: 0.3497
# Epoch 158/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1603 - mean_absolute_error: 0.3378
# Epoch 159/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1829 - mean_absolute_error: 0.3731
# Epoch 160/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1606 - mean_absolute_error: 0.3376
# Epoch 161/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1738 - mean_absolute_error: 0.3528
# Epoch 162/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1436 - mean_absolute_error: 0.3173
# Epoch 163/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1479 - mean_absolute_error: 0.3244
# Epoch 164/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1810 - mean_absolute_error: 0.3584
# Epoch 165/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1505 - mean_absolute_error: 0.3080
# Epoch 166/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1327 - mean_absolute_error: 0.3111
# Epoch 167/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1479 - mean_absolute_error: 0.3340
# Epoch 168/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1775 - mean_absolute_error: 0.3420
# Epoch 169/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1716 - mean_absolute_error: 0.3456
# Epoch 170/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1323 - mean_absolute_error: 0.3145
# Epoch 171/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.1318 - mean_absolute_error: 0.3095
# Epoch 172/200
# 3/3 [==============================] - 0s 53ms/step - loss: 0.1473 - mean_absolute_error: 0.3138
# Epoch 173/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.1534 - mean_absolute_error: 0.3251
# Epoch 174/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.1371 - mean_absolute_error: 0.3036
# Epoch 175/200
# 3/3 [==============================] - 0s 49ms/step - loss: 0.1398 - mean_absolute_error: 0.2997
# Epoch 176/200
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1349 - mean_absolute_error: 0.3064
# Epoch 177/200
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1362 - mean_absolute_error: 0.3115
# Epoch 178/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1431 - mean_absolute_error: 0.3312
# Epoch 179/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1459 - mean_absolute_error: 0.3347
# Epoch 180/200
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1266 - mean_absolute_error: 0.2930
# Epoch 181/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1578 - mean_absolute_error: 0.3272
# Epoch 182/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1674 - mean_absolute_error: 0.3533
# Epoch 183/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1402 - mean_absolute_error: 0.3057
# Epoch 184/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1346 - mean_absolute_error: 0.3011
# Epoch 185/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1395 - mean_absolute_error: 0.3235
# Epoch 186/200
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1451 - mean_absolute_error: 0.3132
# Epoch 187/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.1392 - mean_absolute_error: 0.3169
# Epoch 188/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1702 - mean_absolute_error: 0.3487
# Epoch 189/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1384 - mean_absolute_error: 0.3246
# Epoch 190/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1275 - mean_absolute_error: 0.3069
# Epoch 191/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1211 - mean_absolute_error: 0.2983
# Epoch 192/200
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1343 - mean_absolute_error: 0.3085
# Epoch 193/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1383 - mean_absolute_error: 0.3078
# Epoch 194/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1363 - mean_absolute_error: 0.3113
# Epoch 195/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1298 - mean_absolute_error: 0.2915
# Epoch 196/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1396 - mean_absolute_error: 0.3050
# Epoch 197/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1499 - mean_absolute_error: 0.3384
# Epoch 198/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1242 - mean_absolute_error: 0.2963
# Epoch 199/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1280 - mean_absolute_error: 0.2790
# Epoch 200/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1286 - mean_absolute_error: 0.3026
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# <ipython-input-35-2d5bc51efce8>:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Product['Previsão_M1'] = m1
# <ipython-input-35-2d5bc51efce8>:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Product['Previsão_M2'] = m2
# <ipython-input-35-2d5bc51efce8>:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
# Epoch 75/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3848 - mean_absolute_error: 0.5081
# Epoch 76/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3816 - mean_absolute_error: 0.5185
# Epoch 77/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4027 - mean_absolute_error: 0.5061
# Epoch 78/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3626 - mean_absolute_error: 0.4910
# Epoch 79/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.4163 - mean_absolute_error: 0.5238
# Epoch 80/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3661 - mean_absolute_error: 0.5130
# Epoch 81/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3806 - mean_absolute_error: 0.5002
# Epoch 82/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3635 - mean_absolute_error: 0.5056
# Epoch 83/200
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3997 - mean_absolute_error: 0.5181
# Epoch 84/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4081 - mean_absolute_error: 0.5373
# Epoch 85/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.3578 - mean_absolute_error: 0.4948
# Epoch 86/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4259 - mean_absolute_error: 0.5449
# Epoch 87/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3874 - mean_absolute_error: 0.5250
# Epoch 88/200
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3227 - mean_absolute_error: 0.4840
# Epoch 89/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3787 - mean_absolute_error: 0.5114
# Epoch 90/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.4033 - mean_absolute_error: 0.5264
# Epoch 91/200
# 3/3 [==============================] - 0s 49ms/step - loss: 0.3993 - mean_absolute_error: 0.5360
# Epoch 92/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3668 - mean_absolute_error: 0.4926
# Epoch 93/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3685 - mean_absolute_error: 0.5064
# Epoch 94/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3049 - mean_absolute_error: 0.4727
# Epoch 95/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3684 - mean_absolute_error: 0.4982
# Epoch 96/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3900 - mean_absolute_error: 0.5028
# Epoch 97/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3630 - mean_absolute_error: 0.4792
# Epoch 98/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.4313 - mean_absolute_error: 0.5316
# Epoch 99/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.3795 - mean_absolute_error: 0.5215
# Epoch 100/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.3509 - mean_absolute_error: 0.4785
# Epoch 101/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3457 - mean_absolute_error: 0.4873
# Epoch 102/200
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3571 - mean_absolute_error: 0.4859
# Epoch 103/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.3632 - mean_absolute_error: 0.4834
# Epoch 104/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2968 - mean_absolute_error: 0.4498
# Epoch 105/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3235 - mean_absolute_error: 0.4708
# Epoch 106/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2934 - mean_absolute_error: 0.4764
# Epoch 107/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.3140 - mean_absolute_error: 0.4811
# Epoch 108/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3143 - mean_absolute_error: 0.4787
# Epoch 109/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2809 - mean_absolute_error: 0.4419
# Epoch 110/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2590 - mean_absolute_error: 0.4283
# Epoch 111/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5161 - mean_absolute_error: 0.5956
# Epoch 112/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3138 - mean_absolute_error: 0.4595
# Epoch 113/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3179 - mean_absolute_error: 0.4638
# Epoch 114/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2926 - mean_absolute_error: 0.4556
# Epoch 115/200
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2741 - mean_absolute_error: 0.4284
# Epoch 116/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3354 - mean_absolute_error: 0.5042
# Epoch 117/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2920 - mean_absolute_error: 0.4613
# Epoch 118/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3312 - mean_absolute_error: 0.4787
# Epoch 119/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3360 - mean_absolute_error: 0.4928
# Epoch 120/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3066 - mean_absolute_error: 0.4669
# Epoch 121/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2739 - mean_absolute_error: 0.4421
# Epoch 122/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2466 - mean_absolute_error: 0.4133
# Epoch 123/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3416 - mean_absolute_error: 0.4840
# Epoch 124/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2671 - mean_absolute_error: 0.4338
# Epoch 125/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2846 - mean_absolute_error: 0.4592
# Epoch 126/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2964 - mean_absolute_error: 0.4493
# Epoch 127/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2873 - mean_absolute_error: 0.4283
# Epoch 128/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3165 - mean_absolute_error: 0.4631
# Epoch 129/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2871 - mean_absolute_error: 0.4595
# Epoch 130/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3614 - mean_absolute_error: 0.4940
# Epoch 131/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2436 - mean_absolute_error: 0.4150
# Epoch 132/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2265 - mean_absolute_error: 0.4053
# Epoch 133/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2299 - mean_absolute_error: 0.4219
# Epoch 134/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.2061 - mean_absolute_error: 0.3741
# Epoch 135/200
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2332 - mean_absolute_error: 0.4141
# Epoch 136/200
# 3/3 [==============================] - 0s 53ms/step - loss: 0.2398 - mean_absolute_error: 0.4099
# Epoch 137/200
# 3/3 [==============================] - 0s 51ms/step - loss: 0.3460 - mean_absolute_error: 0.5036
# Epoch 138/200
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2245 - mean_absolute_error: 0.4100
# Epoch 139/200
# 3/3 [==============================] - 0s 51ms/step - loss: 0.1840 - mean_absolute_error: 0.3630
# Epoch 140/200
# 3/3 [==============================] - 0s 51ms/step - loss: 0.2118 - mean_absolute_error: 0.3842
# Epoch 141/200
# 3/3 [==============================] - 0s 49ms/step - loss: 0.1910 - mean_absolute_error: 0.3764
# Epoch 142/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.1665 - mean_absolute_error: 0.3332
# Epoch 143/200
# 3/3 [==============================] - 0s 51ms/step - loss: 0.1639 - mean_absolute_error: 0.3455
# Epoch 144/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.1794 - mean_absolute_error: 0.3619
# Epoch 145/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2033 - mean_absolute_error: 0.3606
# Epoch 146/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.1365 - mean_absolute_error: 0.3138
# Epoch 147/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.1400 - mean_absolute_error: 0.3021
# Epoch 148/200
# 3/3 [==============================] - 0s 51ms/step - loss: 0.2247 - mean_absolute_error: 0.4027
# Epoch 149/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2219 - mean_absolute_error: 0.3974
# Epoch 150/200
# 3/3 [==============================] - 0s 51ms/step - loss: 0.1596 - mean_absolute_error: 0.3226
# Epoch 151/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1659 - mean_absolute_error: 0.3417
# Epoch 152/200
# 3/3 [==============================] - 0s 49ms/step - loss: 0.1696 - mean_absolute_error: 0.3375
# Epoch 153/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.1620 - mean_absolute_error: 0.3377
# Epoch 154/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2152 - mean_absolute_error: 0.4027
# Epoch 155/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1727 - mean_absolute_error: 0.3386
# Epoch 156/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1646 - mean_absolute_error: 0.3162
# Epoch 157/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2810 - mean_absolute_error: 0.4359
# Epoch 158/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1894 - mean_absolute_error: 0.3602
# Epoch 159/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1320 - mean_absolute_error: 0.3081
# Epoch 160/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1702 - mean_absolute_error: 0.3516
# Epoch 161/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1800 - mean_absolute_error: 0.3604
# Epoch 162/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1976 - mean_absolute_error: 0.3721
# Epoch 163/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1899 - mean_absolute_error: 0.3655
# Epoch 164/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1268 - mean_absolute_error: 0.2803
# Epoch 165/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1303 - mean_absolute_error: 0.2913
# Epoch 166/200
# 3/3 [==============================] - 0s 48ms/step - loss: 0.1550 - mean_absolute_error: 0.3412
# Epoch 167/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1269 - mean_absolute_error: 0.2991
# Epoch 168/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1918 - mean_absolute_error: 0.3368
# Epoch 169/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1682 - mean_absolute_error: 0.3402
# Epoch 170/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1462 - mean_absolute_error: 0.3129
# Epoch 171/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1772 - mean_absolute_error: 0.3477
# Epoch 172/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1953 - mean_absolute_error: 0.3644
# Epoch 173/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1390 - mean_absolute_error: 0.2937
# Epoch 174/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1161 - mean_absolute_error: 0.2669
# Epoch 175/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1293 - mean_absolute_error: 0.2960
# Epoch 176/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1610 - mean_absolute_error: 0.3487
# Epoch 177/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1676 - mean_absolute_error: 0.3340
# Epoch 178/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1259 - mean_absolute_error: 0.2995
# Epoch 179/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1253 - mean_absolute_error: 0.2671
# Epoch 180/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1893 - mean_absolute_error: 0.3486
# Epoch 181/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1640 - mean_absolute_error: 0.3451
# Epoch 182/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1271 - mean_absolute_error: 0.2792
# Epoch 183/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1664 - mean_absolute_error: 0.3486
# Epoch 184/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1642 - mean_absolute_error: 0.3247
# Epoch 185/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1704 - mean_absolute_error: 0.3579
# Epoch 186/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1325 - mean_absolute_error: 0.2949
# Epoch 187/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1336 - mean_absolute_error: 0.3110
# Epoch 188/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0968 - mean_absolute_error: 0.2485
# Epoch 189/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1397 - mean_absolute_error: 0.3140
# Epoch 190/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1398 - mean_absolute_error: 0.2937
# Epoch 191/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0954 - mean_absolute_error: 0.2447
# Epoch 192/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1263 - mean_absolute_error: 0.2972
# Epoch 193/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1481 - mean_absolute_error: 0.3404
# Epoch 194/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1399 - mean_absolute_error: 0.2879
# Epoch 195/200
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1298 - mean_absolute_error: 0.2994
# Epoch 196/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1408 - mean_absolute_error: 0.3070
# Epoch 197/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1034 - mean_absolute_error: 0.2732
# Epoch 198/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1422 - mean_absolute_error: 0.3117
# Epoch 199/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1266 - mean_absolute_error: 0.2882
# Epoch 200/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1640 - mean_absolute_error: 0.3322
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# <ipython-input-35-2d5bc51efce8>:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Product['Previsão_M1'] = m1
# <ipython-input-35-2d5bc51efce8>:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Product['Previsão_M2'] = m2
# <ipython-input-35-2d5bc51efce8>:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Product['Previsão_M3'] = m3

# %%
Boot
# Out:
#                       dt_sale ds_product_line   qt_sale    Previsão_M1  \
# 190 2022-12-01 00:00:00+00:00            Boot  263267.0  269772.375000
# 192 2023-01-01 00:00:00+00:00            Boot  223118.0  224920.890625
# 196 2023-02-01 00:00:00+00:00            Boot  215163.0  226787.843750
# 201 2023-03-01 00:00:00+00:00            Boot  184398.0  235043.687500
#
#        Previsão_M2    Previsão_M3
# 190  269843.062500  269754.937500
# 192  224919.187500  224874.843750
# 196  226788.250000  226787.671875
# 201  235040.265625  235039.796875

# %%
Sandals
# Out:
#                       dt_sale ds_product_line   qt_sale   Previsão_M1  \
# 191 2022-12-01 00:00:00+00:00         Sandals  661730.0  525456.00000
# 193 2023-01-01 00:00:00+00:00         Sandals  576581.0  520226.78125
# 197 2023-02-01 00:00:00+00:00         Sandals  573049.0  536253.25000
# 202 2023-03-01 00:00:00+00:00         Sandals  481353.0  569855.37500
#
#      Previsão_M2  Previsão_M3
# 191  525389.5000  524818.6250
# 193  522026.0000  521866.4375
# 197  536114.8125  537886.1875
# 202  569336.5625  567620.8125

# %%
Shoes
# Out:
#                       dt_sale ds_product_line    qt_sale   Previsão_M1  \
# 189 2022-12-01 00:00:00+00:00           Shoes  1227099.0  1.214072e+06
# 194 2023-01-01 00:00:00+00:00           Shoes  1052338.0  9.752893e+05
# 198 2023-02-01 00:00:00+00:00           Shoes   944811.0  7.652919e+05
# 200 2023-03-01 00:00:00+00:00           Shoes   812154.0  7.810138e+05
#
#       Previsão_M2   Previsão_M3
# 189  1.214021e+06  1.214099e+06
# 194  9.756326e+05  9.771203e+05
# 198  7.657587e+05  7.660679e+05
# 200  7.817388e+05  7.832118e+05

# %%
Sneakers
# Out:
#                       dt_sale ds_product_line   qt_sale   Previsão_M1  \
# 188 2022-12-01 00:00:00+00:00        Sneakers  564820.0  562232.50000
# 195 2023-01-01 00:00:00+00:00        Sneakers  521048.0  479190.50000
# 199 2023-02-01 00:00:00+00:00        Sneakers  511301.0  456582.71875
# 203 2023-03-01 00:00:00+00:00        Sneakers  441090.0  466623.31250
#
#       Previsão_M2   Previsão_M3
# 188  562193.18750  560747.12500
# 195  479203.09375  478965.00000
# 199  456539.28125  456611.59375
# 203  466140.09375  466529.93750

# %% [markdown]
# ### Utilizando o Prophet

# %%
#Prophet
#Separando em Treino e Teste
data_limite = pd.to_datetime("2023-02-01").date()

#set de treino
train_ts = df_boot[:data_limite]
train_ts = train_ts.drop('ds_product_line', axis = 1)
#set de teste
test_ts = df_boot[data_limite:]
test_ts = test_ts.drop(columns='ds_product_line')

print("Tamanho do conjunto de treino: ", train_ts.shape)
print("Tamanho do conjunto de teste:  ", test_ts.shape)

# %%
# ajuste do dataset de treino
train_ts = train_ts.reset_index()
train_ts.columns = ['ds', 'y']
train_ts.tail()

# %%
# Ajuste do dataset de teste
test_ts = test_ts.reset_index()
test_ts.columns = ['ds', 'y']
print(test_ts.head())
print(test_ts.tail())

# %%
m = Prophet()
m.fit(train_ts)

# %%
# construção do dataset de teste para alimentar o modelo
#future = m.make_future_dataframe(periods=len(test_ts), freq = 'MS') # freq MS = períodos mensais
future = m.make_future_dataframe(periods=1, freq = 'MS')
# realiza previsão
forecast = m.predict(future)

# %%
# plot dos resultados
m.plot(forecast);

# %%
# plot das componentes da série
m.plot_components(forecast);

# %%
# função para construir dataset com valores históricos e previsão realizada
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))

# %%
# usa função para construir dataset
prophet_forecast_1 = make_comparison_dataframe(pd.concat((train_ts, test_ts), axis = 0), forecast)

prophet_forecast_1.tail()

# %%
# função reutilizável para cálculo de erros
def calculate_forecast_errors(df, prediction_size):

    df = df.copy()

    df['e'] = df['y'] - df['yhat']
    df['p'] = 100 * df['e'] / df['y']

    predicted_part = df[-prediction_size:]

    error_mean = lambda error_name: np.mean(np.abs(predicted_part[error_name]))

    return {'MAPE': error_mean('p'), 'MAE': error_mean('e')}

# %%
# cálculo de erros
for err_name, err_value in calculate_forecast_errors(prophet_forecast_1, len(test_ts)).items():
    print(err_name, err_value)
    #Mean absolute percentage error
    #Mean absolute error

# %%
# plot dos resultados
fig = plt.figure()
plt.title("Resultados 1")
plt.plot(train_ts['ds'],train_ts['y'], color = 'black', label='Treino')
plt.plot(test_ts['ds'],test_ts['y'],color='orange', label='Real')
plt.plot(prophet_forecast_1['yhat'], color='red', label='Prophet')
fig.autofmt_xdate()
leg = plt.legend()

# %%
#yhat = previsto e y = valor real da base
prophet_forecast_1.tail()
